# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremontoya155/VisualizacionMontoya/blob/main/VisualizacionMontoya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
"""
CONSIGNA
  1)Cargar este("/content/HRDataset_v14 .csv") archivo en Python. Realizar estadísticas descriptivas básicas
  2)Realizar un histograma con los salarios. Qué rango(s) de salarios son los más populares?
  3)Realizar un gráfico de violín con los salarios, discriminados por género. 
  4)Graficar la serie de tiempo correspondiente a la fecha de contratación (DateofHire)



"""
# Out:
# '\nCONSIGNA\n  1)Cargar este("/content/HRDataset_v14 .csv") archivo en Python. Realizar estadísticas descriptivas básicas\n  2)Realizar un histograma con los salarios. Qué rango(s) de salarios son los más populares?\n  3)Realizar un gráfico de violín con los salarios, discriminados por género. \n  4)Graficar la serie de tiempo correspondiente a la fecha de contratación (DateofHire)\n\n\n\n'

# %%
#Caso de ejercicio 1
def functionUno():
         df=pd.read_csv("/content/HRDataset_v14 .csv")
         return df
#Caso de ejercicio 2
def functionDos(dataFrame):
    salarios=dataFrame["Salary"]
    cantidadEmpleado=len(salarios)
    print("Para la cantidad del empleados:"+str(cantidadEmpleado))
    print("\nSe muestra la variedad del sueldo de los empleados tomando el valor del sueldo como el dato en x")
    print("\nZona mas cargada en la grafica marca el rango de sueldo mas popular\n")
    fig,ax=plt.subplots()

    ax.set_title("Histograma de salarios")
    ax.set_xlabel("Valor del salario")
    ax.set_ylabel("Razon de empleados ")
    ax.hist(salarios.values.flatten(),color="red",ec="black",bins=25,label="Salarios")
    ax.legend()

    fig.show()
#Caso de ejercicio 3
def functionTres(dataFrame):
    dfUtilizar=dataFrame[["Salary","GenderID"]]
    dfUtilizar=dfUtilizar.replace({0:"Femenino,",1:"Masculino"})
    ax=sns.catplot(x="GenderID",y="Salary",kind="violin",data=dfUtilizar,split=False,palette="Reds")
    ax.set(title="Distribucion de salario")
    
#Caso de ejercicio 4
def functionCuatro(dataFrame):
      años=dataFrame["DateofHire"]
      fechas=pd.DatetimeIndex(años)
      fechasDefinitivo=fechas.strftime("%Y")
      #Este 312 surge porque saque el tamaño de la lista
      lista=list(range(1,312))
      fig,ax=plt.subplots(figsize=(20,15))
      ax.plot(lista,listaFecha,"o:r",label="Fechas de contrataciones")
      ax.set(xlabel="Nº año de ingreso",ylabel="Año",title="Años de ingreso")
      ax.legend()
      fig.show()

# %%
#Traemos el dataFrame
df=functionUno();

# %%
#Mostramos el dataFrame
df.head(5)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
#Usamos el describe para ver las acciones basicas en el dataFrame
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
functionDos(df)
# Out:
# Para la cantidad del empleados:311
#
# Se muestra la variedad del sueldo de los empleados tomando el valor del sueldo como el dato en x
#
# Zona mas cargada en la grafica marca el rango de sueldo mas popular

# %%
functionTres(df)

# %%
functionCuatro(df)
